# %%
from super_resolution.src.config import import_test

# %%
import_test()
# Out:
# 'Hello world'

# %%
import torch
import torchvision
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
pwd()
# Out:
# '/Users/nazeefhamid/Documents/Courses/STAT3007/Project/stat3007-project'

# %%
anji = torch.load("/Users/nazeefhamid/Documents/Courses/STAT3007/Project/ANJI/ANJI_C_V_50RQV_2018-04-09_05m_b2b3b4b8.pt")

# %%
anji = anji / 10000

# %%
anji.shape
# Out:
# torch.Size([259, 4, 256, 256])

# %%
img = anji[0]

# %%
img.shape
# Out:
# torch.Size([4, 256, 256])

# %%
transform = torchvision.transforms.ToPILImage(mode = "CMYK")

# %%
transform(anji[100])
# Out:
# <PIL.Image.Image image mode=CMYK size=256x256>
